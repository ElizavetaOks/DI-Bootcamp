# %% [markdown]
# ## Exercises XP

# %% [markdown]
# ##🌟 Exercise 1: Implementing And Comparing Normalization Techniques
#
# Create a synthetic dataset with two features: FeatureA and FeatureB, where FeatureA is in the range of [0, 1000] and FeatureB is in the range of [0, 10].
# Apply Min-Max Scaling to this dataset and visualize the results using a scatter plot.
# Apply Z-score Normalization to the same dataset and visualize these results as well.
# Write a short analysis comparing the effects of both normalization techniques on the dataset. Discuss which technique might be more appropriate based on the distribution and range of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd
import seaborn as sns

# %%
# Generate synthetic dataset
np.random.seed(42)
num_samples = 1000
FeatureA = np.random.rand(num_samples) * 1000
FeatureB = np.random.rand(num_samples) * 10

# %%
# Apply Min-Max Scaling
min_max_scaler = MinMaxScaler()
min_max_scaled_data = min_max_scaler.fit_transform(np.column_stack((FeatureA, FeatureB)))
FeatureA_minmax, FeatureB_minmax = min_max_scaled_data[:, 0], min_max_scaled_data[:, 1]

# Create a scatter plot for Min-Max Scaled dataset
plt.subplot(1, 3, 2)
plt.scatter(FeatureA_minmax, FeatureB_minmax, alpha=0.5)
plt.title('Min-Max Scaling')
plt.xlabel('FeatureA (Min-Max Scaled)')
plt.ylabel('FeatureB (Min-Max Scaled)')

plt.show()

# %%
# Apply Z-score Normalization
z_score_scaler = StandardScaler()
z_score_normalized_data = z_score_scaler.fit_transform(np.column_stack((FeatureA, FeatureB)))
FeatureA_zscore, FeatureB_zscore = z_score_normalized_data[:, 0], z_score_normalized_data[:, 1]

# Create a scatter plot for Z-score Normalized dataset
plt.subplot(1, 3, 3)
plt.scatter(FeatureA_zscore, FeatureB_zscore, alpha=0.5)
plt.title('Z-score Normalization')
plt.xlabel('FeatureA (Z-score Normalized)')
plt.ylabel('FeatureB (Z-score Normalized)')

plt.tight_layout()
plt.show()

# %% [markdown]
# * If the dataset has outliers and you want to preserve their influence, Min-Max Scaling might be more appropriate.
# * If the dataset is approximately normally distributed and doesn't have significant outliers, Z-score Normalization may be suitable.

# %% [markdown]
# ##🌟 Exercise 2 : Analyzing The Impact Of Min-Max Scaling On Synthetic Data
#
# Create a synthetic dataset with two features: FeatureA and FeatureB. Let FeatureA range from 1 to 100 and FeatureB range from 1,000 to 10,000.
# Apply Min-Max Scaling to this dataset using Python and the MinMaxScaler from Scikit-Learn.
# Visualize the original and scaled datasets using line plots or scatter plots (using Matplotlib or Seaborn).
# Write a brief analysis on how Min-Max Scaling transformed the data, focusing on the change in the range of values for both features.

# %%
# Generate synthetic dataset
np.random.seed(42)
num_samples = 100
FeatureA = np.random.randint(1, 101, num_samples)
FeatureB = np.random.randint(1000, 10001, num_samples)

# %%
# Visualize the original dataset
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(FeatureA, FeatureB, alpha=0.5)
plt.title('Original Dataset')
plt.xlabel('FeatureA')
plt.ylabel('FeatureB')
# Out:
# Text(0, 0.5, 'FeatureB')

# %%
# Apply Min-Max Scaling
min_max_scaler = MinMaxScaler()
min_max_scaled_data = min_max_scaler.fit_transform(np.column_stack((FeatureA, FeatureB)))
FeatureA_minmax, FeatureB_minmax = min_max_scaled_data[:, 0], min_max_scaled_data[:, 1]

# Visualize the Min-Max Scaled dataset
plt.subplot(1, 2, 2)
plt.scatter(FeatureA_minmax, FeatureB_minmax, alpha=0.5)
plt.title('Min-Max Scaled Dataset')
plt.xlabel('FeatureA (Min-Max Scaled)')
plt.ylabel('FeatureB (Min-Max Scaled)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Min-Max Scaling has effectively transformed the dataset, ensuring that all values fall within a standardized range. This normalization is particularly useful when different features have different units or ranges, allowing for fair comparisons and preventing certain features from dominating the others during analysis or modeling. In this case, both features have been scaled to the [0, 1] range, preserving their relative relationships while making them comparable on a consistent scale.
#
#
# ---
#
# ---
#
#
#
# ---

# %% [markdown]
# ##🌟 Exercise 3: Experimenting With Z-Score Normalization On Simulated Data
#
# Generate a simulated dataset with two features: FeatureX and FeatureY. Let FeatureX be normally distributed around a mean of 50 with a standard deviation of 10, and FeatureY be normally distributed around a mean of 500 with a standard deviation of 100. Apply Z-score Normalization to this dataset using Python and the StandardScaler from Scikit-Learn.
# Create visualizations (such as histograms or box plots) of the original and normalized datasets to compare their distributions.
# Discuss the effects of Z-score Normalization on the dataset, particularly how it alters the mean and standard deviation of the features.

# %%
# Generate simulated dataset
np.random.seed(42)
num_samples = 1000
FeatureX = np.random.normal(loc=50, scale=10, size=num_samples)
FeatureY = np.random.normal(loc=500, scale=100, size=num_samples)

# %%
# Visualize the original dataset
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(FeatureX, bins=30, alpha=0.5, label='FeatureX')
plt.hist(FeatureY, bins=30, alpha=0.5, label='FeatureY')
plt.title('Original Dataset')
plt.legend()

# %%
# Apply Z-score Normalization
z_score_scaler = StandardScaler()
z_score_normalized_data = z_score_scaler.fit_transform(np.column_stack((FeatureX, FeatureY)))
FeatureX_zscore, FeatureY_zscore = z_score_normalized_data[:, 0], z_score_normalized_data[:, 1]

# Visualize the Z-score Normalized dataset
plt.subplot(1, 2, 2)
plt.hist(FeatureX_zscore, bins=30, alpha=0.5, label='FeatureX (Z-score Normalized)')
plt.hist(FeatureY_zscore, bins=30, alpha=0.5, label='FeatureY (Z-score Normalized)')
plt.title('Z-score Normalized Dataset')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Z-score Normalization is useful when we want to compare variables with different units or scales. It transforms the data to a standardized distribution, making it easier to interpret and analyze. In the visualizations, you can observe how the shape of the original distributions is maintained, but the values are scaled to a common standard.
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ##🌟 Exercise 4 : Identifying Outliers With Box Plots And Z-Scores
#
# Load the Boston Housing Dataset into a Python environment.
# Use box plots to visually identify potential outliers in various features like ‘CRIM’ (crime rate), ‘RM’ (average number of rooms per dwelling), and ‘MEDV’ (Median value of owner-occupied homes in $1000’s).
# Calculate Z-scores for these features and identify data points that have a Z-score higher than 3 or lower than -3.
# Reflect on how outliers identified by box plots and Z-scores overlap or differ.

# %%
# Load the Boston Housing Dataset
df=pd.read_csv(r'/content/HousingData.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
# Extract the features of interest
features_of_interest = ['CRIM', 'RM', 'MEDV']
subset_df = df[features_of_interest]

# %%
import pylab

# Visualize potential outliers using box plots
plt.figure(figsize=(12, 5))
plt.subplot (2, 2, 1)
sns.boxplot(x=subset_df["CRIM"])
pylab.title ("Box plot of CRIM")

plt.subplot (2, 2, 3)
sns.boxplot(x=subset_df["RM"])
pylab.title ("Box plot of RM")

plt.subplot (1, 2, 2)
sns.boxplot(x=subset_df["MEDV"])
pylab.title ("Box plot of MEDV")

plt.tight_layout()
plt.show()

# %%
# Calculate Z-scores for selected features
z_score_scaler = StandardScaler()
z_scores = z_score_scaler.fit_transform(subset_df)

# %%
# Identify data points with Z-scores higher than 3 or lower than -3
outliers_mask = np.abs(z_scores) > 3
outliers_indices = np.argwhere(outliers_mask)

# %%
# Display indices of outliers
print("Indices of outliers:")
print(outliers_indices)
# Out:
# Indices of outliers:
# [[225   1]
#  [257   1]
#  [262   1]
#  [364   1]
#  [365   1]
#  [367   1]
#  [374   1]
#  [380   0]
#  [398   0]
#  [404   0]
#  [405   0]
#  [406   1]
#  [410   0]
#  [414   0]
#  [418   0]
#  [427   0]]

# %%
# Display values of outliers
print("\nValues of outliers:")
print(subset_df.values[outliers_indices[:, 0], :])
# Out:
# Values of outliers:
# [[ 0.52693  8.725   50.     ]
#  [ 0.61154  8.704   50.     ]
#  [     nan  8.398   48.8    ]
#  [ 3.47428  8.78    21.9    ]
#  [ 4.55587  3.561   27.5    ]
#  [13.5222   3.863   23.1    ]
#  [18.4982   4.138   13.8    ]
#  [88.9762   6.968   10.4    ]
#  [38.3518   5.453    5.     ]
#  [41.5292   5.531    8.5    ]
#  [67.9208   5.683    5.     ]
#  [20.7162   4.138   11.9    ]
#  [51.1358   5.757   15.     ]
#  [45.7461   4.519    7.     ]
#  [73.5341   5.957    8.8    ]
#  [37.6619   6.202   10.9    ]]

# %% [markdown]
# Reflecting on the results, we can compare the outliers identified by box plots and Z-scores. Box plots provide a visual representation of the spread of the data and highlight potential outliers based on interquartile range. Z-scores, on the other hand, provide a numerical measure of how far each data point is from the mean in terms of standard deviations.

# %% [markdown]
# ## 🌟 Exercise 5 : Handling Outliers In A Large Dataset
#
# Load the New York City Airbnb dataset.
# Identify outliers in the ‘price’ column using the IQR method.
# Apply three different outlier handling techniques: trimming, capping, and transformation.
# Analyze the effect of each technique on the distribution of the ‘price’ feature.
# Discuss the pros and cons of each technique in the context of this dataset.

# %%
df_NY = pd.read_csv(r'/content/AB_NYC_2019.csv')
df_NY.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Identify outliers in the ‘price’ column
Q1 = df_NY['price'].quantile(0.25)
Q3 = df_NY['price'].quantile(0.75)
IQR = Q3 - Q1

# Defining bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filtering the outliers
outliers = df_NY[(df_NY['price'] < lower_bound) | (df_NY['price'] > upper_bound)]

# %%
# Apply outlier handling techniques
# 1. Trimming: Remove outliers
trimmed_data = df_NY[(df_NY['price'] >= lower_bound) & (df_NY['price'] <= upper_bound)]

# 2. Capping: Cap outliers at the upper bound
capped_data = df_NY.copy()
capped_data['price'] = capped_data['price'].clip(lower=None, upper=upper_bound)

# 3. Transformation: Log-transform the 'price' feature
transformed_data = df_NY.copy()
transformed_data['price'] = np.log1p(transformed_data['price'])

# %%
# Visualize the effects of each technique
plt.figure(figsize=(15, 6))

# Original distribution
plt.subplot(1, 4, 1)
sns.histplot(df_NY['price'], bins=50, kde=True)
plt.title('Original Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Trimming
plt.subplot(1, 4, 2)
sns.histplot(trimmed_data['price'], bins=50, kde=True)
plt.title('Trimmed Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Capping
plt.subplot(1, 4, 3)
sns.histplot(capped_data['price'], bins=50, kde=True)
plt.title('Capped Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Transformation
plt.subplot(1, 4, 4)
sns.histplot(transformed_data['price'], bins=50, kde=True)
plt.title('Log-Transformed Distribution')
plt.xlabel('Log')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##🌟 Exercise 6 : Impact Of Outliers On Data Analysis
#
# Load the Wine Quality Dataset.
# Identify outliers in key features like ‘fixed acidity’, ‘residual sugar’, and ‘alcohol’ using your preferred method.
# Calculate the mean and standard deviation of these features with and without outliers.
# Analyze how outliers affect the interpretation of these features.
# Reflect on the importance of considering outliers in data analysis, especially in a context like wine quality assessment.

# %%
df_wine = pd.read_csv(r'/content/WineQT.csv')
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
# Identify outliers using IQR method for 'fixed acidity'
Q1_fa = df_wine['fixed acidity'].quantile(0.25)
Q3_fa = df_wine['fixed acidity'].quantile(0.75)
IQR_fa = Q3_fa - Q1_fa
lower_bound_fa = Q1_fa - 1.5 * IQR_fa
upper_bound_fa = Q3_fa + 1.5 * IQR_fa
outliers_fa = df_wine[(df_wine['fixed acidity'] < lower_bound_fa) | (df_wine['fixed acidity'] > upper_bound_fa)]

# %%
# Identify outliers using IQR method for 'residual sugar'
Q1_rs = df_wine['residual sugar'].quantile(0.25)
Q3_rs = df_wine['residual sugar'].quantile(0.75)
IQR_rs = Q3_rs - Q1_rs
lower_bound_rs = Q1_rs - 1.5 * IQR_rs
upper_bound_rs = Q3_rs + 1.5 * IQR_rs
outliers_rs = df_wine[(df_wine['residual sugar'] < lower_bound_rs) | (df_wine['residual sugar'] > upper_bound_rs)]

# %%
# Identify outliers using IQR method for 'alcohol'
Q1_al = df_wine['alcohol'].quantile(0.25)
Q3_al = df_wine['alcohol'].quantile(0.75)
IQR_al = Q3_al - Q1_al
lower_bound_al = Q1_al - 1.5 * IQR_al
upper_bound_al = Q3_al + 1.5 * IQR_al
outliers_al = df_wine[(df_wine['alcohol'] < lower_bound_rs) | (df_wine['alcohol'] > upper_bound_rs)]

# %%
# Calculate mean and standard deviation with outliers
mean_fa_with_outliers = df_wine['fixed acidity'].mean()
std_fa_with_outliers = df_wine['fixed acidity'].std()

# Remove outliers
wine_df_no_outliers_fa = df_wine[(df_wine['fixed acidity'] >= lower_bound_fa) & (df_wine['fixed acidity'] <= upper_bound_fa)]

# Calculate mean and standard deviation without outliers
mean_fa_no_outliers = wine_df_no_outliers_fa['fixed acidity'].mean()
std_fa_no_outliers = wine_df_no_outliers_fa['fixed acidity'].std()

print(f'Mean (with outliers): {mean_fa_with_outliers}, Std (with outliers): {std_fa_with_outliers}')
print(f'Mean (without outliers): {mean_fa_no_outliers}, Std (without outliers): {std_fa_no_outliers}')
# Out:
# Mean (with outliers): 8.311111111111112, Std (with outliers): 1.74759501716954
# Mean (without outliers): 8.116651501364876, Std (without outliers): 1.4672208582644437

# %%
# Calculate mean and standard deviation with outliers
mean_rs_with_outliers = df_wine['residual sugar'].mean()
std_rs_with_outliers = df_wine['residual sugar'].std()

# Remove outliers
wine_df_no_outliers_rs = df_wine[(df_wine['residual sugar'] >= lower_bound_rs) & (df_wine['residual sugar'] <= upper_bound_rs)]

# Calculate mean and standard deviation without outliers
mean_rs_no_outliers = wine_df_no_outliers_fa['residual sugar'].mean()
std_rs_no_outliers = wine_df_no_outliers_fa['residual sugar'].std()

print(f'Mean (with outliers): {mean_rs_with_outliers}, Std (with outliers): {std_rs_with_outliers}')
print(f'Mean (without outliers): {mean_rs_no_outliers}, Std (without outliers): {std_rs_no_outliers}')
# Out:
# Mean (with outliers): 2.5321522309711284, Std (with outliers): 1.3559174666826799
# Mean (without outliers): 2.506687898089172, Std (without outliers): 1.3542597383565518

# %%
# Calculate mean and standard deviation with outliers
mean_al_with_outliers = df_wine['alcohol'].mean()
std_al_with_outliers = df_wine['alcohol'].std()

# Remove outliers
wine_df_no_outliers_al = df_wine[(df_wine['alcohol'] >= lower_bound_al) & (df_wine['alcohol'] <= upper_bound_al)]

# Calculate mean and standard deviation without outliers
mean_al_no_outliers = wine_df_no_outliers_al['alcohol'].mean()
std_al_no_outliers = wine_df_no_outliers_al['alcohol'].std()

print(f'Mean (with outliers): {mean_al_with_outliers}, Std (with outliers): {std_al_with_outliers}')
print(f'Mean (without outliers): {mean_al_no_outliers}, Std (without outliers): {std_al_no_outliers}')
# Out:
# Mean (with outliers): 10.442111402741325, Std (with outliers): 1.0821956098764445
# Mean (without outliers): 10.405363984674329, Std (without outliers): 1.0263979902834446
