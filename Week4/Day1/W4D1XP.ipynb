# %% [markdown]
# # **Exercise 1: Introduction To Data Analysis**
#
# 1. What is data analysis? Why is data analysis important in modern contexts?
#
# Data analysis, the process of examining and interpreting data, is a critical component of decision-making in contemporary contexts.
# Its importance lies in its ability to transform raw data into actionable insights, guiding informed decision-making in various fields.
#
# 2. List and describe three areas where data analysis is applied today.
#
# *Healthcare:*
# In healthcare, data analysis improves patient outcomes, optimizes operations, and advances medical research through electronic health records and predictive modeling.
#
# *E-commerce and Retail:*
# E-commerce platforms leverage data analysis for understanding customer behavior, optimizing supply chains, and enhancing the overall shopping experience.
#
# *Smart Cities and Urban Planning:*
# Data analysis contributes to efficient urban management by utilizing information from sensors and social media to enhance public services and optimize infrastructure.

# %% [markdown]
# #**Exercise 2: Dataset Loading And Initial Analysis**
#
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.
#
# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd

# %%
sleeping = pd.read_csv(r'/Time Americans Spend Sleeping.csv')
health = pd.read_csv(r'/Mental health Depression disorder Data.csv')
credit = pd.read_csv(r'/clean_dataset.csv')
# Out:
# <ipython-input-8-a722fb827fef>:2: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   health = pd.read_csv(r'/Mental health Depression disorder Data.csv')

# %%
sleeping.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# ---
#
#
#
# ---
#
#
# This dataset contains information about the year, period, average sleep duration per day, age group, gender, activity and gender.

# %%
health.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %% [markdown]
# ---
#  This dataset contains information about the country, year, and percentage of a different types of diseases.

# %%
credit.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# ---
#
#
# This dataset contains information about gender, age, amount of
# debt, marital status, industry, ethnisity, years of work and other credit information

# %% [markdown]
# #**Exercise 3: Identifying Data Types**
#
# For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %% [markdown]
# ***bd_sleeping***
# index - quantitative - serial,
# year - quantitative - integer,
# period - qualitative - str object,
# avg hrs per day sleeping - quantitative - maths solution,
# standart error - quantitative - statistic value,
# type of days - qualitative - str object,
# Age Group - qualitative - str object,
# Activity - qualitative - str object,
# Sex - qualitative - str object.
#
# **bd_health**
# index - quantitative - serial number,
# Entity - qualitative - str object,
# Code - qualitative - str object,
# Year - quantitative - integer,
# Schizophrenia (%) - quantitative - statistic value,
# Bipolar disorder (%)- quantitative - statistic value,
# Eating disorders (%)- quantitative - statistic value,
# Anxiety disorders (%)- quantitative - statistic value,
# Drug use disorders (%)- quantitative - statistic value,
# Depression (%) -quantitative - statistic value,
# Alcohol use disorders (%) - quantitative - statistic value.
#
# **bd_credit**
# Gender - quantitative - integer (0/1),
# Age - quantitative - float,
# Debt- quantitative - float,
# Married - quantitative - integer (0/1),
# BankCustomer - quantitative - integer (0/1),
# Industry- qualitative - object
# Ethnicity - qualitative - object
# YearsEmployed  quantitative - float,
# PriorDefault quantitative - integer (0/1),
# Employed - quantitative - integer (0/1),
# CreditScore - quantitative - integer,
# DriversLicense - quantitative - integer (0/1),
# Citizen - qualitative - object,
# ZipCode- quantitative - integer,
# Income - quantitative - integer,
# Approved - quantitative - integer (0/1).

# %% [markdown]
# #**Exercise 4: Exploring Data Types**
#
#
# Objective: Learn About Different Types Of Data In Data Analysis.
# Task:
# Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.

# %%
iris = pd.read_csv(r'/IRIS.csv')

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# In IRIS database there are 5 columns - 4 of them have float type, so we could classified them as qualitative. And column "species" has object type, so it's quantitative.

# %% [markdown]
# # Exercise 5: Basic Data Analysis With Google Colab
#
#
# Objective: Perform Basic Data Analysis Using Google Colab.
# Task:
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries :

# %%
from scipy.stats import mode

# %%
mean_length = iris['petal_length'].mean()
median_length = iris['petal_length'].median()
mode_length = mode(iris['petal_length'])

print(f"Mean length: {mean_length:.2f}")
print(f"Median length: {median_length}")
print(f"Mode length: {mode_length}")
# Out:
# Mean length: 3.76
# Median length: 4.35
# Mode length: ModeResult(mode=1.5, count=14)

# %%
import matplotlib.pyplot as plt
plt.plot(iris['species'], iris['petal_length'])
plt.show()

# %% [markdown]
# Document your findings in the notebook:
#
# Iris-virginica has the biggest petal lenght, while Iris-setosa has the smallest.

# %% [markdown]
# # Exercise 6: Basic Observation Skills In Data Analysis
#
#
# Objective: Develop Observation Skills For Data Analysis.
# Task:
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
sleeping.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
sleeping.dtypes
# Out:
# index                         int64
# Year                          int64
# Period                       object
# Avg hrs per day sleeping    float64
# Standard Error              float64
# Type of Days                 object
# Age Group                    object
# Activity                     object
# Sex                          object
# dtype: object

# %% [markdown]
# **Trend Analysis:**
#
# Year: This column is crucial for trend analysis, allowing you to observe how sleep patterns change over time.
# Avg hrs per day sleeping: The average hours of sleep per day provide the primary metric for trend analysis.
#
# Analyzing sleep duration trends over multiple years can help identify patterns, shifts, or changes in sleep habits among Americans.
# Plotting the average hours of sleep per day against the year can reveal long-term trends and potential correlations with external factors.
#
# **Group Comparison (Age Group, Sex):**
#
# Age Group: Allows for the comparison of sleep patterns across different age groups.
# Sex: Enables the comparison of sleep patterns between different genders.
# Avg hrs per day sleeping: The primary metric for group comparison.
#
# Comparing sleep patterns across age groups can help identify variations in sleep duration among different life stages.
# Analyzing sleep duration differences between genders may reveal potential disparities or trends.
