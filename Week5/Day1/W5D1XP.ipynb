# %% [markdown]
# # 🌟 Exercise 1 : Understanding Data Visualization
# Instructions
# Explain why data visualization is important in data analysis.
#
# Describe the purpose of a line graph in data visualization.

# %% [markdown]
# ---
#
#
# Data visualization is crucial in data analysis because it allows complex datasets to be presented in a visual format, making patterns, trends, and insights more easily understandable. Visual representations like charts and graphs enhance comprehension, facilitate decision-making, and enable the communication of findings to diverse audiences.
#
# The purpose of a line graph in data visualization is to depict the relationship between two continuous variables over a continuous interval. It is particularly useful for illustrating trends and patterns over time, helping analysts and decision-makers identify correlations, fluctuations, and overall patterns in the data.

# %% [markdown]
# # 🌟 Exercise 2 : Creating A Line Plot For Temperature Variation

# %% [markdown]
# Create a simple line plot using Matplotlib that represents the temperature variations over a week.
#
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.

# %%
import matplotlib.pyplot as plt

Day = [i for i in range(1, 8)]
Temperature_F = [67, 71, 75, 71, 73, 74, 80]

plt.plot(Day, Temperature_F, color='green', linestyle='-.', linewidth=2, marker='o',
         markerfacecolor='blue', markersize=6)
plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.title('The Temperature variations over a Week')

plt.show()

# %% [markdown]
# # 🌟 Exercise 3 : Visualizing Monthly Sales With A Bar Chart

# %% [markdown]
# Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
#
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.

# %%
Month = [i for i in range(1, 13)]
Sales_Amount = [6700, 7100, 7050, 7001, 7300, 5874, 8000, 5014, 9214, 4583, 7000, 6850]

plt.plot(Month, Sales_Amount, color='blue', linestyle='dotted', linewidth=2, marker='h',
         markerfacecolor='blue', markersize=8)
plt.xlabel('Month')
plt.ylabel('Sales Amount ($)')
plt.title('The Monthly Sales')

plt.show()

# %% [markdown]
# # 🌟 Exercise 4 : Data Visualisation

# %% [markdown]
# Using the dataset sales_data.csv
#
# Calculate the total quantity of products sold by the company.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'/content/sales_data.csv')
df
# Out:
#            date     product     category   price  quantity  revenue
# 0    2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1    2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2    2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3    2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4    2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ..          ...         ...          ...     ...       ...      ...
# 364  2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [369 rows x 6 columns]

# %%
df.drop_duplicates()
# Out:
#            date     product     category   price  quantity  revenue
# 0    2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1    2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2    2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3    2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4    2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# ..          ...         ...          ...     ...       ...      ...
# 364  2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing   100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics   100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0
#
# [368 rows x 6 columns]

# %%
total_quantity = df.quantity.sum()
total_quantity
# Out:
# 5360.0

# %% [markdown]
# Identify the category that had the highest revenue and calculate how much revenue it generated.

# %%
df.groupby('category', as_index = False).agg({'revenue':'sum'}).sort_values(by = 'revenue', ascending=False)
# Out:
#       category   revenue
# 5  Electronics  516080.0
# 0  Accessories  104700.0
# 4     Clothing   94350.0
# 6        Shoes   20640.0
# 1         Bags   19500.0
# 3     Clohting    1200.0
# 7      Shoeses     960.0
# 2         Bgas     900.0

# %% [markdown]
# Determine the average revenue per sale in the dataset.

# %%
df.dtypes
# Out:
# date         object
# product      object
# category     object
# price       float64
# quantity    float64
# revenue     float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df['quarter'] = df.date.dt.quarter

# %%
quarter_mapping = {1: 'Q1', 2: 'Q2', 3: 'Q3', 4: 'Q4'}
df['quarter'] = df['quarter'].map(quarter_mapping)

# %%
df
# Out:
#           date     product     category   price  quantity  revenue quarter
# 0   2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0      Q1
# 1   2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0      Q1
# 2   2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0      Q1
# 3   2022-01-03  Headphones  Electronics   100.0      20.0   2000.0      Q1
# 4   2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0      Q1
# ..         ...         ...          ...     ...       ...      ...     ...
# 364 2022-12-27       Watch  Accessories   150.0       5.0    750.0      Q4
# 365 2022-12-28        Coat     Clothing   100.0       5.0    500.0      Q4
# 366 2022-12-29  Headphones  Electronics   100.0      10.0   1000.0      Q4
# 367 2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0      Q4
# 368 2022-12-31      Hoodie     Clothing    40.0      30.0   1200.0      Q4
#
# [369 rows x 7 columns]

# %%
df.groupby('quarter', as_index = False).agg({'revenue':'mean'})
# Out:
#   quarter      revenue
# 0      Q1  1979.347826
# 1      Q2  2044.111111
# 2      Q3  2148.695652
# 3      Q4  2070.000000

# %% [markdown]
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
quarter_revenue = df.groupby('quarter', as_index = False).agg({'revenue':'sum'})
quarter_revenue
# Out:
#   quarter   revenue
# 0      Q1  182100.0
# 1      Q2  183970.0
# 2      Q3  197680.0
# 3      Q4  194580.0

# %%
import matplotlib.pyplot as plt

x = [i for i in quarter_revenue['quarter']]
y = [i for i in quarter_revenue['revenue']]

plt.bar(x,y, color=['red', 'yellow', 'orange', 'blue'], edgecolor='black', hatch='.')
plt.ylabel('Revenue in $')
plt.title('Total revenue per quarter')

plt.show()

# %% [markdown]
# # 🌟 Exercise 5 : Data Visualisation Using MatPlotLib

# %% [markdown]
# Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.

# %%
x = [i for i in range(-10, 11)]
y_2 = [i**2 for i in x]
plt.plot(x, y_2, label='x squared 2', color='pink',linestyle='-', linewidth=2, marker='o',
         markerfacecolor='yellow', markersize=6)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Simple Line Plot')
plt.legend()
plt.show()

# %% [markdown]
# Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.

# %%
products = ['A', 'B', 'C', 'D']
sales = [15, 30, 45, 20]

plt.bar(products, sales, color=['lightblue'], edgecolor='black', hatch='*')
plt.title('Products Sales Data')
plt.xlabel('Products')
plt.ylabel('Sales values')
plt.show()

# %% [markdown]
# Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %%
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
people = [40,30,20,10]

plt.figure(figsize=(6, 6))
explode = (0.05, 0.05, 0.05, 0.05)
plt.pie(people, labels=fruits, autopct='%1.1f%%', explode=explode)
plt.title('Favorite fruits of a group of people')
plt.show()
